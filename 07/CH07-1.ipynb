# %% [markdown]
# # 01. 取得鏡頭影像的基本架構

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import mediapipe as mp
mp.solutions.hands.Hands??

# %% [markdown]
# # 02. 定義手的資訊變數

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)
# 02. 定義手的資訊變數
mpHands = mp.solutions.hands
hands = mpHands.Hands()


while True:
    success, img = cap.read()
    # 02. 取得multi_hand_landmarks的資料 
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    print(results.multi_hand_landmarks)

    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # # 03. 劃出關鍵點

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)
# 02. 定義手的資訊變數
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=2)
# 03. 定義畫圖單元
mpDraw = mp.solutions.drawing_utils



while True:
    success, img = cap.read()
    # 02. 取得multi_hand_landmarks的資料 
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    #print(results.multi_hand_landmarks)
    # 03. 劃出關鍵點
    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mpDraw.draw_landmarks(img, handLms)


    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 04.劃出關鍵點間的連結

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)
# 02. 定義手的資訊變數
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=2)
# 03. 定義畫圖單元
mpDraw = mp.solutions.drawing_utils



while True:
    success, img = cap.read()
    # 02. 取得multi_hand_landmarks的資料 
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    #print(results.multi_hand_landmarks)
    # 03. 劃出關鍵點
    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mpDraw.draw_landmarks(img, handLms,mpHands.HAND_CONNECTIONS) #mpHands.HAND_CONNECTIONS 04.劃出關鍵點間的連結


    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 05. fps時間變數

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)
# 02. 定義手的資訊變數
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=2)
# 03. 定義畫圖單元
mpDraw = mp.solutions.drawing_utils

# 05. fps時間變數
cTime = 0
pTime = 0


while True:
    success, img = cap.read()
    # 02. 取得multi_hand_landmarks的資料 
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    #print(results.multi_hand_landmarks)
    # 03. 劃出關鍵點
    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mpDraw.draw_landmarks(img, handLms,mpHands.HAND_CONNECTIONS) #mpHands.HAND_CONNECTIONS 04.劃出關鍵點間的連結
    # 05. 輸出fps
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime
    cv2.putText(img, str(int(fps)), (20, 50), cv2.FONT_HERSHEY_PLAIN, 3, (255,0,0), 3)


    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # # 06. 顯示出食指的位置

# %%
import cv2
import mediapipe as mp
import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)
# 02. 定義手的資訊變數
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=2)
# 03. 定義畫圖單元
mpDraw = mp.solutions.drawing_utils

# 05. fps時間變數
cTime = 0
pTime = 0


while True:
    success, img = cap.read()
    # 02. 取得multi_hand_landmarks的資料 
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    #print(results.multi_hand_landmarks)
    # 03. 劃出關鍵點
    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            # 06. 顯示出食指的位置
            for id, lm in enumerate(handLms.landmark):
                #print(id, lm)  #印出檢查關鍵點座標
                h, w, c = img.shape
                cx, cy=int(lm.x*w), int(lm.y*h)
                #print(id, cy, cx)  #印出轉換後的關鍵點座標
                if id == 12 or id==4:
                    cv2.circle(img, (cx, cy), 15, (255, 0, 0), cv2.FILLED)

            mpDraw.draw_landmarks(img, handLms,mpHands.HAND_CONNECTIONS) #mpHands.HAND_CONNECTIONS 04.劃出關鍵點間的連結
    # 05. 輸出fps
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime
    cv2.putText(img, str(int(fps)), (20, 50), cv2.FONT_HERSHEY_PLAIN, 3, (255,0,0), 3)


    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 07. 改寫成類別呼叫的方式儲存成HandTrackingModule.py

# %%
import cv2
import mediapipe as mp
import time

class handDetector():
    def __init__(self, mode=False, maxHands = 2, model_comp = 1, detectionCon=0.5, trackCon=0.5):
        self.mode = mode
        self.maxHnads = maxHands
        self.model_comp = model_comp
        self.detectionCon = detectionCon
        self.trackCon = trackCon

# %%
import cv2
import mediapipe as mp
import time

class handDetector():
    def __init__(self, mode=False, maxHands = 2, model_comp = 1, detectionCon=0.5, trackCon=0.5):
        self.mode = mode
        self.maxHands = maxHands
        self.model_comp = model_comp
        self.detectionCon = detectionCon
        self.trackCon = trackCon

        # 02. 定義手的資訊變數
        self.mpHands = mp.solutions.hands
        self.hands = self.mpHands.Hands(self.mode,self.maxHands,self.model_comp,self.detectionCon,self.trackCon)
        # 03. 定義畫圖單元
        self.mpDraw =mp.solutions.drawing_utils


    def findHands(self, img, draw = True):
        imgRGB=cv2.cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        self.results=self.hands.process(imgRGB)
    
        # 03. 劃出關鍵點
        if self.results.multi_hand_landmarks:
            for handLms in self.results.multi_hand_landmarks:
                if draw:
                    self.mpDraw.draw_landmarks(img,handLms,self.mpHands.HAND_CONNECTIONS)
    
        return img 
    def findPosition(self, img, handNo=0, draw=True):
        lmList = []
        if self.results.multi_hand_landmarks:
            if (handNo == -1) :
                for hid, myHand in enumerate(self.results.multi_hand_landmarks):
                    for id, lm in enumerate(myHand.landmark):
                        #print(id, lm)  #印出檢查關鍵點座標
                        h, w, c = img.shape
                        cx, cy=int(lm.x*w), int(lm.y*h)
                        #print(id, cy, cx)  #印出轉換後的關鍵點座標
                        lmList.append([id, cx, cy])
                        if draw:
                            cv2.circle(img, (cx, cy), 5, (hid*100+100, 255-hid*100, 255), cv2.FILLED)
            else:
                if len(self.results.multi_hand_landmarks) > handNo:
                    myHand = self.results.multi_hand_landmarks[handNo]
                    for id, lm in enumerate(myHand.landmark):
                        #print(id, lm)  #印出檢查關鍵點座標
                        h, w, c = img.shape
                        cx, cy=int(lm.x*w), int(lm.y*h)
                        #print(id, cy, cx)  #印出轉換後的關鍵點座標
                        lmList.append([id, cx, cy])
                        if draw:
                            cv2.circle(img, (cx, cy), 5, (255, 0, 0), cv2.FILLED)

        return lmList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4788/3147572271.py in <module>
#      34
#      35
# ---> 36 cap.release()
#      37 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
import cv2
import HandTrackingModule as htm    # 07.自訂的HandTrackingModule.py

import time

# 01. 取得鏡頭影像的基本架構
cap = cv2.VideoCapture(0)

# 07. 定義手的資訊變數
detector = htm.handDetector()

# 05. fps時間變數
cTime = 0
pTime = 0


while True:
    success, img = cap.read()
    
    # 08. 呼叫findHands劃出關鍵點與連結
    img = detector.findHands(img, draw = True)
    # 09. 呼叫findPosition劃出自訂關鍵點
    lmList = detector.findPosition(img, -1, draw = True)
   
    for id, lm in enumerate(lmList):
        if lm[0]==8 or  lm[0] ==4:
            cv2.circle(img, (lm[1], lm[2]), 10, (100, 100, 255), cv2.FILLED)
            print(lm)          
    # 05. 輸出fps
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime
    cv2.putText(img, str(int(fps)), (20, 50), cv2.FONT_HERSHEY_PLAIN, 3, (255,0,0), 3)


    
    cv2.imshow("Image", img)
    # 01. 按Q離開
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# [4, 89, 212]
# [8, -10, 384]
# [4, 400, 347]
# [8, 85, 446]
# [4, 364, 317]
# [8, 52, 414]
# [4, 329, 237]
# [8, 39, 307]
# [4, 355, 213]
# [8, 90, 277]
# [4, 370, 213]
# [8, 110, 273]
# [4, 377, 211]
# [8, 117, 278]
# [4, 381, 207]
# [8, 129, 280]
# [4, 387, 195]
# [8, 136, 271]
# [4, 390, 192]
# [8, 138, 255]
# [4, 363, 193]
# [8, 131, 239]
# [4, 334, 182]
# [8, 120, 228]
# [4, 331, 180]
# [8, 114, 222]
# [4, 314, 172]
# [8, 111, 215]
# [4, 283, 105]
# [8, 151, 171]
# [4, 279, 96]
# [8, 158, 162]
# [4, 271, 80]
# [8, 176, 151]
# [4, 267, 79]
# [8, 186, 140]
# [4, 258, 73]
# [8, 210, 120]
# [4, 234, 72]
# [8, 204, 123]
# [4, 298, 154]
# [8, 179, 152]
# [4, 370, 198]
# [8, 118, 217]
# [4, 377, 187]
# [8, 120, 221]
# [4, 378, 186]
# [8, 120, 226]
# [4, 382, 182]
# [8, 123, 215]
# [4, 377, 188]
# [8, 119, 223]
# [4, 380, 186]
# [8, 121, 221]
# [4, 366, 193]
# [8, 118, 222]
# [4, 308, 111]
# [8, 190, 140]
# [4, 295, 97]
# [8, 207, 121]
# [4, 305, 100]
# [8, 213, 122]
# [4, 289, 98]
# [8, 222, 105]
# [4, 301, 99]
# [8, 226, 107]
# [4, 325, 151]
# [8, 206, 140]
# [4, 392, 197]
# [8, 128, 227]
# [4, 405, 200]
# [8, 137, 244]
# [4, 405, 201]
# [8, 141, 242]
# [4, 413, 198]
# [8, 144, 242]
# [4, 408, 192]
# [8, 133, 245]
# [4, 406, 193]
# [8, 128, 244]
# [4, 402, 192]
# [8, 119, 250]
# [4, 425, 190]
# [8, 150, 226]
# [4, 433, 172]
# [8, 166, 132]
# [4, 330, 230]
# [8, 155, 165]
# [4, 326, 252]
# [8, 152, 176]
# [4, 322, 310]
# [8, 149, 235]
# [4, 327, 319]
# [8, 162, 250]
# [4, 342, 321]
# [8, 188, 253]
# [4, 355, 305]
# [8, 211, 243]
# [4, 375, 295]
# [8, 233, 235]
# [4, 369, 294]
# [8, 230, 236]
# [4, 366, 295]
# [8, 228, 239]
# [4, 361, 294]
# [8, 224, 241]
# [4, 356, 295]
# [8, 221, 242]
# [4, 353, 299]
# [8, 217, 244]
# [4, 350, 304]
# [8, 212, 250]
# [4, 347, 307]
# [8, 209, 254]
# [4, 349, 312]
# [8, 210, 257]
# [4, 355, 314]
# [8, 213, 262]
# [4, 357, 323]
# [8, 226, 249]
# [4, 352, 325]
# [8, 223, 239]
# [4, 376, 219]
# [8, 279, 189]

# %% [markdown]
# # hw

# %%
import cv2
import time
import numpy as np
import HandTrackingModule as htm    #自訂的HandTrackingModule.py
import math

# 07. 增加AndreMiras/pycaw
from ctypes import cast, POINTER
from comtypes import CLSCTX_ALL
from pycaw.pycaw import AudioUtilities, IAudioEndpointVolume


# 01. 取得鏡頭影像的基本架構
wCam, hCam = 640, 480
cap = cv2.VideoCapture(0)
cap.set(3, wCam)
cap.set(4, hCam)

pTime = 0
# 03. 抓取手的資訊
detector = htm.handDetector(detectionCon=0.7)

# 07. 增加AndreMiras/pycaw
devices = AudioUtilities.GetSpeakers()
interface = devices.Activate(
    IAudioEndpointVolume._iid_, CLSCTX_ALL, None)
volume = cast(interface, POINTER(IAudioEndpointVolume))
volRange = volume.GetVolumeRange()
minVol = volRange[0]
maxVol = volRange[1]

# 08. 設定長條數值變數
val = 0
volBar = 400
volPer = 0
while True:
    success, img = cap.read()
    
    # 03. 抓取手的資訊
    img = detector.findHands(img)
    lmList = detector.findPosition(img, draw=False)

    # 04. 劃出食指與拇指
    if len(lmList)!=0:
        #print(lmList[4], lmList[8])
        x1, y1 = lmList[4][1], lmList[4][2]
        x2, y2 = lmList[8][1], lmList[8][2]
        x3, y3 = lmList[12][1], lmList[12][2]
        cv2.circle(img, (x1, y1), 10, (255, 0, 0), cv2.FILLED)
        cv2.circle(img, (x2, y2), 10, (255, 0, 0), cv2.FILLED)
        cv2.circle(img, (x3, y3), 10, (255, 0, 0), cv2.FILLED)
        # 05. 計算與劃出食指與拇指的連線與中心點
        cx, cy = (x1+x2)//2, (y1+y2)//2
        zx, zy = (x2+x3)//2, (y2+y3)//2
        cv2.line(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
        cv2.line(img, (x2, y2), (x3, y3), (255, 0, 255), 3)
        cv2.circle(img, (cx, cy), 10, (0, 255, 255), cv2.FILLED)
        cv2.circle(img, (zx, zy), 10, (0, 255, 255), cv2.FILLED)
        # 06. 算出兩點的距離
        length = math.hypot(x2-x1, y2-y1)
        length1 = math.hypot(x3-x2, y3-y2)
        
        if length1<60:
            # 08. 設定長條數值
            volBar = np.interp(length, [40, 160], [400, 150])
            volPer = np.interp(length, [40, 160], [0, 100])
            vol = np.interp(10*math.log10((volPer+1)/101), [-20, 0], [minVol, maxVol])  # 09. 更換公式
            volume.SetMasterVolumeLevel(vol, None)
            cv2.putText(img, f'L:{int(length), vol}', (180, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 3)
        else:
            cv2.circle(img, (cx, cy), 10, (0, 255, 0), cv2.FILLED)
        #print(length)
        #cv2.putText(img, f'L:{int(length)}', (320, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 3)
        
        #if length < 50:
            #cv2.circle(img, (cx, cy), 10, (0, 255, 0), cv2.FILLED)
        # 07. 距離轉換音量
        # hand range 40-160
        # Volume Range -65-0
        if length < 40:
            cv2.circle(img, (cx, cy), 10, (0, 255, 0), cv2.FILLED)

    # 08. 劃出長條圖
    cv2.rectangle(img, (50, int(volBar)), (85, 400), (0, 255, 0), cv2.FILLED)
    cv2.rectangle(img, (50, 150), (85, 400), (0, 80, 0), 3)
    cv2.putText(img, f'{int(volPer)}%', (45, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,125,0), 3)

    
    # 02. 輸出fps
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime
    cv2.putText(img, f'FPS:{int(fps)}', (20, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 3)

    cv2.imshow("Image", img)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
